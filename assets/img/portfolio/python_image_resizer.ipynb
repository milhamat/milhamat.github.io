# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
path = 'app-1.jpg'

# %%
# Read Images
img = mpimg.imread(path)

# Output Images
plt.imshow(img)

# %%
image=np.array(img)
print(image.shape)
# Out:
# (768, 1024, 3)

# %% [markdown]
# ### The default images is HxW (`768`x`1024`)

# %%
# Pillow is a fork of PIL, so we’re importing from PIL
from PIL import Image

# Load an image from a file
puffin_image = Image.open('ml_app.jpg')

# To display a Pillow image object in Jupyter Notebook,
# just run a cell whose result is that image. 
puffin_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1122x917>

# %%
# If you’re using the Python REPL instead of Jupyter Notebook,
# use Image.show() to create a temporary file for the image
# and display it with the default system image viewer.

# puffin_image.show()

# %%
# The file format of the source file.
print(f"Image's file format: {puffin_image.format}")
# Out:
# Image's file format: JPEG

# %%
# The pixel format used by the image. Typical values are "1", "L", "RGB", or "CMYK."
print(f"Image’s pixel format: {puffin_image.mode}")
# Out:
# Image’s pixel format: RGB

# %%
# Image size, in pixels. The size is given as a 2-tuple (width, height).
print(f"Image size (width, height): {puffin_image.size}")
# Out:
# Image size (width, height): (1122, 917)

# %%
# Colour palette table, if any.
print(f"Image palette: {puffin_image.palette}")

# %%
# Image.resize() makes a resized copy of the original image.
puffin_image_resized = puffin_image.resize((1024, 768))
puffin_image_resized
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
puffin_image_resized.save('ml_app_rz.jpg')

# %%
# image = Image.open('demo_image.jpg')
# new_image = image.resize((400, 400))
# new_image.save('image_400.jpg')

# print(image.size) # Output: (1920, 1280)
# print(new_image.size) # Output: (400, 400)

# %%
def image_resize(name:str) -> None:
    puffin_image = Image.open(f'{name}.jpg')
    puffin_image_resized = puffin_image.resize((1024, 768))
    puffin_image_resized.save(f'{name}_rz.jpg')

# %%
# image_resize('./ntub_data_dashboard')

# %%
# image_resize('./enhance')

# %%
# image_resize('./steel_surface')

# %%
# image_resize('ntub_1')

# %% [markdown]
# reference [here](https://auth0.com/blog/image-processing-in-python-with-pillow/)
